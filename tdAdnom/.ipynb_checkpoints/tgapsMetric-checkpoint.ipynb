# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

import healpy as hp
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.db as db

# %%
plt.rc('legend', fontsize=20) # using a size in points
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rcParams['axes.labelsize'] = 16

# %%
# load opsim database
dbpath_v15 = "/home/idies/workspace/lsst_cadence/FBS_1.5/"  # path to all opsim databases

dbpath_v17 = "/home/idies/workspace/lsst_cadence/FBS_1.7/"

dbpath_v171 = "/home/idies/workspace/lsst_cadence/FBS_1.7.1/"


# output directory
dataRawDir = '/home/idies/workspace/Temporary/lixl/scratch/outDir/tGaps/'

outDir = '/home/idies/workspace/Temporary/lixl/scratch/outDir/resultsDb/'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
ls '/home/idies/workspace/Temporary/lixl/scratch/outDir/'
# Out:
# dataRaw/       dataRaw_v1_7/    properMotion/  tGaps/
# dataRaw_v1_5/  dataRaw_v1_7_1/  resultsDb/

# %%
# get the name of all opsim dbs 
import glob

workpath = os.getcwd()
#workpath = '/home/idies/workspace/Storage/lixl/persistent/LSST_OpSim/unknowns'

os.chdir(dbpath_v15)  # change to opsim database directory
dblist_v15 = glob.glob('*.db') 

os.chdir(dbpath_v17)  # change to opsim database directory
dblist_v17 = glob.glob('*.db') 

os.chdir(dbpath_v171)  # change to opsim database directory
dblist_v171 = glob.glob('*.db') 

os.chdir(workpath) # change back to work directory

dblist_v15.sort()
dblist_v17.sort()
dblist_v171.sort()

# %%
from lsst.sims.maf.utils import m52snr

class filterPairTGapsMetric(metrics.BaseMetric):
    """
    returns
    N_v * np.exp(-Dkl) for each fields
    
    Parameters:
        colname: 
        fltpair: filter pair, eg ['r', 'i']
        snr_lim: list, signal to noise ratio (fiveSigmaDepth) threshold for fltpair, default [5, 5]
        filename: output a csv table for time gaps of each field
    
    """

    def __init__(self, colname=['observationStartMJD', 'filter', 'fiveSigmaDepth'], fltpair=['r', 'i'], tmin=0, tmax=1.5/24, bins=50, mag_lim=[18, 18],
                 save_dT=False, filename=None, dataout=True, **kwargs):
        self.colname = colname
        self.filename = filename
        self.fltpair = fltpair
        self.mag_lim = mag_lim
        self.dataout = dataout
        self.tmin = tmin
        self.tmax = tmax
        self.bins = bins
        self.save_dT = save_dT
        
        self.Nrun = 0   # record the how many time run run()
        if filename!=None:
            if os.path.isfile(filename):
                # rm old file
                os.system("rm {}".format(filename))
                
        if self.dataout:
            super().__init__(col=self.colname, metricDtype='object', **kwargs)
        else:
            super().__init__(col=self.colname, metricDtype='float', **kwargs)
    
    def save_to_file(self, dic, filename="test_pkl.pkl"):
        '''save dict item to pickle file'''
        
        #df = self.load_from_pkl(filename)

        #df = df.append(pd.DataFrame(dic), ignore_index=True)

        #df.to_pickle(filename)
        df = pd.DataFrame(dic)
        with open(filename, 'a') as f:
            df.to_csv(f, header=f.tell()==0, index=None)
        
    def RADec2pix(self, nside, ra, dec, degree=True):
        """
        Calculate the nearest healpixel ID of an RA/Dec array, assuming nside.
    
        Parameters
        ----------
        nside : int
            The nside value of the healpix grid.
        ra : numpy.ndarray
            The RA values to be converted to healpix ids, in degree by default.
        dec : numpy.ndarray
            The Dec values to be converted to healpix ids, in degree by default.
    
        Returns
        -------
        numpy.ndarray
            The healpix ids.
        """
        if degree:
            ra = np.radians(ra) # change to radians
            dec = np.radians(dec)
        
        lat = np.pi/2. - dec
        hpid = hp.ang2pix(nside, lat, ra )
        return hpid


    def run(self, dataSlice, slicePoint=None):
        
        # return all possible time gaps for each fields
        
        f0 = self.fltpair[0]
        f1 = self.fltpair[1]
        
        #check input config
        #print(f0, f1, self.tmin, self.tmax, self.mag_lim)
            
        # sort dataSlice
        
        idx0 = ( dataSlice['filter'] == f0 ) & ( dataSlice['fiveSigmaDepth'] > self.mag_lim[0])
        idx1 = ( dataSlice['filter'] == f1 ) & ( dataSlice['fiveSigmaDepth'] > self.mag_lim[1])
        
        timeCol0 = np.sort( dataSlice['observationStartMJD'][idx0] )
        timeCol1 = np.sort( dataSlice['observationStartMJD'][idx1] )

        timeCol0 = timeCol0.reshape((len(timeCol0), 1))
        timeCol1 = timeCol1.reshape((len(timeCol1), 1))
        
        # calculate time gaps matrix
        diffmat = np.abs( np.subtract(timeCol0, timeCol1.T) ) 
        
        # collect all time gaps
        if f0==f1:
            # get only triangle part
            dt_tri = np.tril(diffmat, -1)
            dT = dt_tri[dt_tri!=0]    # flatten lower triangle 
        else:
            dT = diffmat.flatten()

        #Nv, Dkl, FoM_i, dT_tlim = self.get_FoM_i(dT, tmin=self.tmin, tmax=self.tmax, bins=self.bins)
        
        dT_tlim = dT[(dT>=self.tmin)&(dT<=self.tmax)] 
        Nv = len(dT_tlim)

        # print(self.Nrun, np.min(dataSlice['fiveSigmaDepth'][idx0]), np.min(dataSlice['fiveSigmaDepth'][idx1]),)
        self.Nrun += 1
        # write results to csv file
        fieldRA = np.mean(dataSlice['fieldRA']) ,
        fieldDec = np.mean(dataSlice['fieldDec']),
        
        if self.save_dT:
            dic = {'Nrun': self.Nrun, 
                'pixId': self.RADec2pix(nside=16, ra=fieldRA, dec=fieldDec)[0],
                'Nv': Nv,
                #'Dkl': Dkl,
                # 'FoM_i': FoM_i,
                'dT_lim': dT_tlim
                  }
        else:
            dic = {'Nrun': self.Nrun, 
                'pixId': RADec2pix(nside=16, ra=fieldRA, dec=fieldDec)[0],
                'Nv': Nv,
                #'Dkl': Dkl,
                #'FoM_i': FoM_i,
                # 'dT_lim': dT_tlim
                  }
            
        if self.filename!=None:
            self.save_to_file(dic, filename=self.filename)
        
        if self.dataout:
            # return dT
            result = dic
            return result
        else:
            #f0 = self.fltpair[0]
            #f1 = self.fltpair[1]
            #result = np.min(dT) if len(dT)!=0 else np.inf
            result = Nv
            return float(result)

# %%
def pix2radec(nside, ipix, degree=True):
    """from ipix to ra/dec"""
    
    theta, phi = hp.pix2ang(nside, ipix)
    ra = phi
    dec = np.pi/2. - theta
    if degree:
        ra = np.rad2deg(ra)
        dec = np.rad2deg(dec)
    return ra, dec

def runMetric(dbname, dbpath, fltpair, ipix_ms=None, nside=16, sqlstr=None,
              colname=['observationStartMJD', 'filter', 'fiveSigmaDepth'],
              tmin=0, tmax=1.5/24, bins=50, mag_lim=[18, 18],
              filename=None, dataout=True, **kwargs
             ):
    """run filterPairTGapsMetric
    dbname: name of opsim database
    fltpair: filter pair, eg: 'ri'
    ipix_ms: pixIds of footprint
    """
    opsdb = db.OpsimDatabase(dbpath+dbname)
    
    #fltpair = ['r', 'i']
    
    if ipix_ms!=None:
        # use UserPointsSlicer for minisurvey
        ra, dec = pix2radec(nside=nside, ipix=ipix_ms)
        slicer = slicers.UserPointsSlicer(ra, dec, latLonDeg=True, badval=0)
    else:
        # use HealpixSlicer 
        slicer = slicers.HealpixSlicer(nside=nside)
    
    # metric, slicer, constraint
    metric = filterPairTGapsMetric( colname=colname, fltpair=fltpair, tmin=tmin, tmax=tmax, bins=bins, mag_lim=mag_lim,
                 filename=filename, dataout=dataout, **kwargs)
    
    sqlconstraint = 'filter in ("{}", "{}")'.format(*fltpair)
    if sqlstr!=None:
        sqlconstraint += ' and {}'.format(sqlstr)
        
    # bundle
    newMetricSky = metricBundles.MetricBundle(metric, slicer, sqlconstraint)
    
    # group bundle
    bundleDict = {'newMetricSky':newMetricSky}
    group = metricBundles.MetricBundleGroup(bundleDict, opsdb, outDir=outDir, resultsDb=resultsDb)
    
    # run
    group.runAll()
    #group.plotAll(closefigs = False)
    return newMetricSky

# %% [markdown]
# ### run for one opsim one filter pair

# %%
dblist_v15[5]
# Out:
# 'baseline_v1.5_10yrs.db'

# %%
# %%time
# test run for baseline
dbname = dblist_v15[5]
metricSky = runMetric( dbname=dbname, dbpath=dbpath_v15, fltpair=['u', 'r'], ipix_ms=None, nside=16, sqlstr='proposalId=1',
              colname=['observationStartMJD', 'filter', 'fiveSigmaDepth'],
              tmin=0, tmax=2, bins=50, mag_lim=[18, 18],
              filename=None, dataout=True, save_dT=True)
# Out:
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 522979 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 9.01 s, sys: 3.38 s, total: 12.4 s
# Wall time: 12.4 s

# %%
arr = metricSky.metricValues.data
arr_valid = arr[ arr != None ]
df = pd.DataFrame.from_records(arr_valid)
df.head(3)
# Out:
#    Nrun  Nv                                             dT_lim  pixId
# 0     1  20  [0.01598771262797527, 0.015814308295375668, 0....   1376
# 1     2  17  [0.0159398090254399, 0.032145169119758066, 0.0...   1377
# 2     3  14  [0.015945262195600662, 0.01593982793565374, 0....   1378

# %%
tmin = 5/60/60/24 # in days
tmax = 1.5/24
#tmax = 2
bins = np.linspace(tmin*24, tmax*24, 50)

dT_all = np.concatenate(df.dT_lim * 24)
plt.hist(dT_all[dT_all<1.5], bins=bins);

# %% [markdown]
# ### run for all filterpairs all opsims

# %%
fltpairs = ['uu', 'ug', 'ur', 'ui', 'uz', 'uy', 'gg', 'gr', 'gi', 'gz', 'gy',
           'rr', 'ri', 'rz', 'ry', 'ii', 'iz', 'iy', 'zz', 'zy', 'yy' ]

# %% [markdown]
# #### run for all opsim v1.5

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'ALL' # minisurvey label used to save files

if 'LMC' in msname:
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    ipix_ms = ipix_SMC
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
#diclist = []
#for Nrun in range( len(ipix_ms) ):
#    dic = {'Nrun': Nrun, 
#                'pixId': ipix_ms[Nrun],
#                'Nv': 0,
#                'Dkl': 0,
#                'FoM_i': 0,
#                'dT_lim': []
#                  }
#    diclist.append(dic)
#arr_empty = np.array(diclist)
#df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v15
for dbname in dblist_v15:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# >>>  agnddf_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 137990 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 348456 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 603123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 606303 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 554463 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 547157 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 210466 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 675599 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 678779 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 626939 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 619633 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 465133 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 933446 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881606 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 874300 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 468313 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 884786 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 877480 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 416473 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 825640 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 409167 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 137491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 354263 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 600897 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 610123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 561025 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555421 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 216772 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 680178 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 689404 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 640306 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 634702 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 463406 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 936038 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 886940 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881336 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 472632 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 896166 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 890562 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 423534 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 841464 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 417930 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 139600 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 362718 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 599038 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 608793 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 562590 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559827 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 223118 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 682556 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 692311 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 646108 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 643345 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 459438 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 928631 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 882428 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 879665 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 469193 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 892183 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 889420 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 422990 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 843217 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 420227 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 126093 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 321954 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557839 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 561231 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 515569 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 510536 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 195861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 627607 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 630999 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 585337 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 580304 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 431746 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 866884 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 821222 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816189 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 435138 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 824614 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819581 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 389476 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 773919 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 384443 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 163685 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387220 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 645181 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 646320 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 604328 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576722 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 223535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 705031 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 706170 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 664178 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 636572 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 481496 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 964131 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 922139 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 894533 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482635 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 923278 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 895672 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 440643 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 853680 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 413037 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 135826 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 347580 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 603469 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 607557 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# ...
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 212571 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 701522 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 705582 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 652106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 667146 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 488951 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 981962 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 928486 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 943526 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 493011 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 932546 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 947586 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 439535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 894110 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 454575 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 131307 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 332884 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597168 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 601006 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 551552 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 565566 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 201577 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 667438 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 671276 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 621822 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 635836 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 465861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 935560 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 886106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 900120 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 469699 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 889944 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 903958 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 420245 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 854504 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 434259 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 6h 40min 12s, sys: 2h 29min 58s, total: 9h 10min 10s
# Wall time: 10h 59min 48s

# %% [markdown]
# #### run for all opsim v1.7

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'ALL' # minisurvey label used to save files

if 'LMC' in msname:
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    ipix_ms = ipix_SMC
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
#diclist = []
#for Nrun in range( len(ipix_ms) ):
#    dic = {'Nrun': Nrun, 
#                'pixId': ipix_ms[Nrun],
#                'Nv': 0,
#                'Dkl': 0,
#                'FoM_i': 0,
#                'dT_lim': []
#                  }
#    diclist.append(dic)
#arr_empty = np.array(diclist)
#df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v17
for dbname in dblist_v17:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# >>>  baseline_nexp1_v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 134526 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 343294 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 600102 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 602991 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 553866 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 545967 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 208768 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 674344 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 677233 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 628108 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 620209 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 465576 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 934041 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 884916 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 877017 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 468465 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 887805 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 879906 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 419340 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 830781 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp1_v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 411441 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 125233 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 319067 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555040 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 558649 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 512839 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 507364 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 193834 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 623641 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 627250 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 581440 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 575965 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 429807 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 863223 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817413 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 811938 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 433416 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 821022 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 815547 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387606 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 769737 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 382131 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 121176 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 329622 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559338 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 547321 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 502175 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 495018 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 208446 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 646608 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 634591 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 589445 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 582288 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 438162 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 864307 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819161 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 812004 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 426145 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 807144 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 799987 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 380999 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 754841 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100_gcbv1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 373842 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 121808 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 324922 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555393 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 546377 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 501374 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 493964 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 203114 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 636699 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 627683 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 582680 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 575270 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 433585 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 858154 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 813151 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 805741 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 424569 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 804135 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 796725 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 379566 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 751722 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl100v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 372156 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 99730 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 382228 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 545400 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 504407 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 462444 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 457195 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 282498 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 728168 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 687175 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 645212 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 639963 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 445670 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 850347 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 808384 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 803135 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 404677 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 767391 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 762142 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 362714 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 720179 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200_gcbv1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 357465 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 97107 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 380433 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 535764 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 495231 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  cadence_drive_gl200v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# ...
# Found 498059 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 191844 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 615880 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 618608 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574234 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 568984 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 424036 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 850800 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 806426 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 801176 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 426764 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 809154 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 803904 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 382390 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 759530 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_50_v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 377140 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 116894 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 306031 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 535211 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 538438 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 495150 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 488496 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 189137 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 607454 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 610681 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 567393 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 560739 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 418317 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 839861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 796573 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 789919 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 421544 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 799800 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 793146 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 378256 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 749858 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  u_long_ms_60_v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 371602 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 5h 15min 8s, sys: 1h 53min 26s, total: 7h 8min 35s
# Wall time: 8h 28min 53s

# %% [markdown]
# #### run for all opsim v1.7.1

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'ALL' # minisurvey label used to save files

if 'LMC' in msname:
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    ipix_ms = ipix_SMC
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
#diclist = []
#for Nrun in range( len(ipix_ms) ):
#    dic = {'Nrun': Nrun, 
#                'pixId': ipix_ms[Nrun],
#                'Nv': 0,
#                'Dkl': 0,
#                'FoM_i': 0,
#                'dT_lim': []
#                  }
#    diclist.append(dic)
#arr_empty = np.array(diclist)
#df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v171
for dbname in dblist_v171:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# >>>  baseline_nexp2_v1.7.1_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 127001 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 321023 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557617 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559262 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 514165 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 507635 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 194022 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 624638 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 626283 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 581186 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574656 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 430616 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 862877 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817780 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 811250 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 432261 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819425 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 812895 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387164 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 767798 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_nexp2_v1.7.1_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 380634 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 124973 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 313044 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 553269 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 556301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 510889 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 508255 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 188071 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 616367 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 619399 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 573987 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 571353 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 428296 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 859624 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 814212 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 811578 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 431328 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817244 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 814610 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 385916 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 769198 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 383282 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 124660 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 313104 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 552949 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555979 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 510860 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 509555 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 188444 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 616733 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 619763 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574644 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 573339 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 428289 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 859608 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 814489 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 813184 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 431319 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817519 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816214 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 386200 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 771095 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 384895 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 127109 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 316410 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555621 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 558345 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 513375 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 516234 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 189301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 617813 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 620537 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 575567 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 578426 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 428512 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 859748 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 814778 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817637 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 431236 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817502 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 820361 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 386266 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 775391 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  footprint_6_v1.7.1_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 389125 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 124867 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 314214 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 554351 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557480 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 512282 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 501066 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 189347 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 618831 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 621960 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576762 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 565546 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 429484 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 862097 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816899 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 805683 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 432613 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 820028 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 808812 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387415 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 763614 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 376199 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 124139 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  full_disk_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# ...
# Found 622000 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 624684 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 579671 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 569678 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 429511 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 861706 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816693 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 806700 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 432195 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819377 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 809384 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387182 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 764371 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 377189 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db uu
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 124801 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ug
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 313271 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ur
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 554595 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ui
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557498 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db uz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 512804 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db uy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 511191 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db gg
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 188470 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db gr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 618264 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db gi
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 621167 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db gz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576473 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db gy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574860 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db rr
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 429794 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ri
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 862491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db rz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 817797 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ry
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816184 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db ii
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 432697 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db iz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 820700 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db iy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819087 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db zz
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 388003 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db zy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 774393 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db yy
# Healpix slicer using NSIDE=16, approximate resolution 219.871130 arcminutes
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 386390 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 41min 29s, sys: 11min 27s, total: 52min 56s
# Wall time: 1h 2min 59s

# %% [markdown]
# ### minisurveys regions: LMC SMC GP

# %%
ipix_LMC = [2899, 2900, 2901, 2934, 2935, 2936, 2965, 2966, 2967, 2992, 2993, 2994]
ipix_SMC = [2960, 2961, 2988, 2989, 3012]
ipix_GP = [ 144,  145,  146,  147,  179,  180,  181,  182,  183,  184,  217,
        218,  219,  225,  226,  260,  261,  271,  272,  307,  308,  320,
        321,  358,  374,  413,  431,  432,  471,  472,  493,  534,  535,
        558,  598,  599,  622,  661,  662,  687,  725,  726,  751,  788,
        789,  790,  815,  816,  852,  853,  854,  879,  915,  916,  917,
        944,  979,  980,  981, 1008, 1042, 1043, 1044, 1045, 1073, 1107,
       1108, 1109, 1136, 1170, 1171, 1172, 1201, 1234, 1235, 1236, 1237,
       1265, 1297, 1298, 1299, 1300, 1330, 1361, 1362, 1363, 1364, 1393,
       1425, 1426, 1427, 1428, 1458, 1489, 1490, 1491, 1492, 1522, 1552,
       1553, 1554, 1555, 1587, 1616, 1617, 1618, 1619, 1620, 1650, 1679,
       1680, 1681, 1682, 1683, 1715, 1744, 1745, 1746, 1747, 1779, 1807,
       1808, 1809, 1810, 1811, 1843, 1871, 1872, 1873, 1874, 1875, 1907,
       1934, 1935, 1936, 1937, 1938, 1972, 1998, 1999, 2000, 2001, 2002,
       2003, 2036, 2062, 2063, 2064, 2065, 2066, 2100, 2126, 2127, 2128,
       2129, 2130, 2164, 2189, 2190, 2191, 2192, 2193, 2194, 2229, 2253,
       2254, 2255, 2256, 2257, 2258, 2293, 2316, 2317, 2318, 2319, 2320,
       2321, 2358, 2380, 2381, 2382, 2383, 2384, 2385, 2421, 2422, 2443,
       2444, 2445, 2446, 2447, 2448, 2449, 2486, 2487, 2507, 2508, 2509,
       2510, 2511, 2512, 2513, 2550, 2551, 2570, 2571, 2572, 2573, 2574,
       2575, 2576, 2614, 2630, 2631, 2632, 2633, 2634, 2635, 2636, 2673,
       2687, 2688, 2689, 2690, 2691, 2692, 2693, 2728, 2729, 2739, 2740,
       2741, 2742, 2743, 2744, 2745, 2746, 2779, 2780, 2781, 2787, 2788,
       2789, 2790, 2791, 2792, 2793, 2794, 2826, 2827, 2828, 2829, 2830,
       2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838, 2839, 2869, 2870,
       2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2908, 2909,
       2910, 2911, 2912, 2913, 2914, 2915, 2916, 2943, 2944, 2945, 2946,
       2947, 2948, 2974, 2975, 2976]

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'SMC_WFD' # minisurvey label used to save files

if 'LMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_SMC
elif 'GP' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_GP
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
diclist = []
for Nrun in range( len(ipix_ms) ):
    dic = {#'Nrun': Nrun, 
                'pixId': ipix_ms[Nrun],
                'Nv': 0,
                'dT_lim': []
                  }
    diclist.append(dic)
arr_empty = np.array(diclist)
df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v15
for dbname in dblist_v15:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# running SMC_WFD
# >>>  agnddf_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 119740 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 291301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 523025 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 524655 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 480697 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 497946 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 171561 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574846 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576476 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 532518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 549767 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 403285 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 808200 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 764242 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 781491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 404915 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 765872 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 783121 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 360957 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 739163 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 378206 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 109443 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 268528 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 485397 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 487961 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 448627 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 466629 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 159085 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 535039 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 537603 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 498269 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 516271 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 375954 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 754472 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 715138 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 733140 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 378518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 717702 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 735704 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 339184 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 696370 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 357186 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 110630 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 274059 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 478756 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482063 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 444062 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 466732 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 163429 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 531555 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 534862 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 496861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 519531 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 368126 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 739559 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 701558 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 724228 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 371433 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 704865 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 727535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 333432 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 689534 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 356102 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 108851 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 267489 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482319 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 484477 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 445941 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 463336 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 158638 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 532106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 534264 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 495728 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 513123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 373468 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 749094 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 710558 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 727953 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 375626 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 712716 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 730111 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 337090 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 691575 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 354485 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 141018 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 320832 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 558675 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559035 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 520745 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 524945 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 179814 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597471 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597831 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559541 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 563741 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 417657 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 835674 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 797384 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 801584 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 418017 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 797744 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 801944 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 379727 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 763654 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 383927 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 117746 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 290758 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 522979 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 525803 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 483064 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 500255 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 173012 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 578245 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 581069 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 538330 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555521 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 405233 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 813290 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 770551 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 787742 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 408057 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 773375 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 790566 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 365318 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 747827 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 382509 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 102041 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 248186 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 438612 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 440529 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 404919 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 423301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 146145 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482716 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 484633 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 449023 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 467405 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# ...
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 601390 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 552066 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 570346 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 196691 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 658510 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 661363 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 612039 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 630319 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 461819 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 926491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 877167 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 895447 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 464672 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 880020 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 898300 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 415348 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 848976 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_1expt_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 433628 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 135198 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 328628 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 589757 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 592936 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 544330 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 562553 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 193430 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 647989 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 651168 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 602562 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 620785 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 454559 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 912297 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 863691 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881914 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 457738 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 866870 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 885093 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 409132 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 836487 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_2ns_5expt_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 427355 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 163085 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 390671 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 691211 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 695395 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 638101 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  short_exp_5ns_1expt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'SMC_ALL' # minisurvey label used to save files

if 'LMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_SMC
elif 'GP' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_GP
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
diclist = []
for Nrun in range( len(ipix_ms) ):
    dic = {#'Nrun': Nrun, 
                'pixId': ipix_ms[Nrun],
                'Nv': 0,
                'dT_lim': []
                  }
    diclist.append(dic)
arr_empty = np.array(diclist)
df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v15
for dbname in dblist_v15:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'GP_WFD' # minisurvey label used to save files

if 'LMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_SMC
elif 'GP' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_GP
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
diclist = []
for Nrun in range( len(ipix_ms) ):
    dic = {#'Nrun': Nrun, 
                'pixId': ipix_ms[Nrun],
                'Nv': 0,
                'dT_lim': []
                  }
    diclist.append(dic)
arr_empty = np.array(diclist)
df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v15
for dbname in dblist_v15:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# running GP_WFD
# >>>  agnddf_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 119740 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 291301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 523025 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 524655 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 480697 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 497946 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 171561 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 574846 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576476 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 532518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 549767 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 403285 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 808200 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 764242 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 781491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 404915 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 765872 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 783121 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 360957 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 739163 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 378206 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 109443 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 268528 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 485397 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 487961 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 448627 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 466629 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 159085 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 535039 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 537603 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 498269 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 516271 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 375954 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 754472 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 715138 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 733140 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 378518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 717702 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 735704 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 339184 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 696370 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 357186 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 110630 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 274059 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 478756 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482063 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 444062 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 466732 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 163429 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 531555 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 534862 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 496861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 519531 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 368126 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 739559 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 701558 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 724228 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 371433 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 704865 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 727535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 333432 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 689534 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 356102 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 108851 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 267489 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482319 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 484477 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 445941 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 463336 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 158638 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 532106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 534264 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 495728 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 513123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 373468 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 749094 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 710558 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 727953 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 375626 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 712716 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 730111 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 337090 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 691575 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 354485 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 141018 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 320832 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 558675 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559035 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 520745 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 524945 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 179814 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597471 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597831 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559541 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 563741 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 417657 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 835674 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 797384 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 801584 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 418017 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 797744 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 801944 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 379727 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 763654 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 383927 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 117746 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 290758 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 522979 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 525803 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 483064 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 500255 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 173012 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 578245 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 581069 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 538330 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555521 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 405233 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 813290 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 770551 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 787742 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 408057 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 773375 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 790566 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 365318 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 747827 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 382509 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 102041 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 248186 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 438612 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 440529 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 404919 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 423301 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 146145 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482716 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 484633 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 449023 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 467405 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# ...
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.95_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 780899 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.95_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 399178 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 128725 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 322674 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 590465 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 592887 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 542443 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 561509 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 193949 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 655689 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 658111 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 607667 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 626733 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 461740 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 925902 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 875458 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 894524 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 464162 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 877880 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 896946 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 413718 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 846502 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 432784 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 122711 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 306492 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 562352 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 564711 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 518051 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 535220 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 183781 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 623422 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 625781 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 579121 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 596290 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 439641 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881641 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 834981 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 852150 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 442000 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 837340 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 854509 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 395340 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 807849 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and proposalId=1 for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 412509 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 3h 7min 9s, sys: 1h 16min 54s, total: 4h 24min 3s
# Wall time: 4h 31min 42s

# %%
# %%time 
# run all filter pairs for all opsims 

nside = 16
# select mini survey footprint 
msname = 'GP_ALL' # minisurvey label used to save files

if 'LMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_LMC
elif 'SMC' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_SMC
elif 'GP' in msname:
    print(f"running {msname}")
    ipix_ms = ipix_GP
else:
    ipix_ms = None

#sqlstr = "night<4000 and proposalId=1"
#sqlstr = None
if 'WFD' in msname:
    sqlstr = "proposalId=1"
else:
    sqlstr = "note not like '%DD%'"

magdic = {'u':18, 'g':18, 'r':18, 'i':18, 'z':18, 'y':18}

#--------------------------------
# empty metricArr 
diclist = []
for Nrun in range( len(ipix_ms) ):
    dic = {#'Nrun': Nrun, 
                'pixId': ipix_ms[Nrun],
                'Nv': 0,
                'dT_lim': []
                  }
    diclist.append(dic)
arr_empty = np.array(diclist)
df_empty = pd.DataFrame.from_records( arr_empty )
#--------------------------------

dbpath = dbpath_v15
for dbname in dblist_v15:
    dataRaw = {}
    dataRaw[dbname] = {}
    for fltpair in fltpairs: 
        
        print(">>> ", dbname, fltpair)

        dataRaw[dbname][fltpair] = {}
        if fltpair[0]==fltpair[1]:
            tmin =  5/60/60/24 # in days
            tmax = 3e8/60./60./24    
            # histogram in log space
            bins=np.logspace(np.log10(tmin), np.log10(tmax), 50)
            
        else:
            #tmin = 5/60/60/24
            tmin = 5/60/60/24  # 5s in days
            #tmax = 1.5/24 # 1.5 hour in days
            tmax = 2  # 2 days
            bins = np.linspace(tmin, tmax, 50)
            
        metricSky = runMetric(dbname, dbpath=dbpath, fltpair=fltpair, sqlstr=sqlstr, nside=nside, ipix_ms=ipix_ms, 
                                 mag_lim=[magdic[fltpair[0]], magdic[fltpair[1]]],
                                 tmin=tmin, tmax=tmax, bins=bins,
                                 filename=None, save_dT=True, dataout=True );
            
        arr = metricSky.metricValues.data 
                
        df = pd.DataFrame.from_records( arr[ arr != None ] )
        
        if len(df)==0:
            df = df_empty
            
        dataRaw[dbname][fltpair] = df[['pixId', 'Nv', 'dT_lim']] 
        
        # save raw data to pickle
        pd.DataFrame( dataRaw ).to_pickle(dataRawDir+'/tgaps_{}_{}.pkl'.format(dbname, msname))
# Out:
# running GP_ALL
# >>>  agnddf_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 137990 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 348456 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 603123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 606303 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 554463 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 547157 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 210466 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 675599 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 678779 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 626939 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 619633 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 465133 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 933446 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881606 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 874300 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 468313 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 884786 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 877480 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 416473 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 825640 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  agnddf_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 409167 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 137491 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 354263 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 600897 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 610123 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 561025 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 555421 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 216772 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 680178 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 689404 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 640306 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 634702 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 463406 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 936038 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 886940 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881336 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 472632 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 896166 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 890562 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 423534 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 841464 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_dust_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 417930 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 139600 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 362718 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 599038 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 608793 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 562590 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 559827 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 223118 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 682556 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 692311 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 646108 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 643345 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 459438 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 928631 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 882428 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 879665 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 469193 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 892183 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 889420 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 422990 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 843217 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 420227 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 126093 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 321954 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557839 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 561231 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 515569 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 510536 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 195861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 627607 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 630999 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 585337 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 580304 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 431746 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 866884 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 821222 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 816189 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 435138 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 824614 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 819581 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 389476 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 773919 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_2snaps_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 384443 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 163685 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 387220 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 645181 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 646320 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 604328 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576722 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 223535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 705031 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 706170 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 664178 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 636572 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 481496 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 964131 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 922139 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 894533 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 482635 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 923278 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 895672 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 440643 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 853680 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_samefilt_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 413037 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 135826 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 347580 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 603469 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 607557 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 557518 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 549786 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 211754 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 679397 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 683485 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 633446 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 625714 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 467643 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 939374 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 889335 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 881603 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 471731 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 893423 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 885691 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 421692 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 835652 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  baseline_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 413960 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 134747 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 350286 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 600482 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 608440 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 556618 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 551150 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 215539 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  bulges_bs_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 681274 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# ...
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.95_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 424902 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 137386 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 349957 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 626337 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 630397 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 576921 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 591961 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 212571 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 701522 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 705582 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 652106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 667146 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 488951 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 981962 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 928486 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 943526 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 493011 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 932546 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 947586 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 439535 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 894110 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_noddf_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 454575 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uu
# Querying database SummaryAllProps with constraint filter in ("u", "u") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 131307 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ug
# Querying database SummaryAllProps with constraint filter in ("u", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 332884 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ur
# Querying database SummaryAllProps with constraint filter in ("u", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 597168 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ui
# Querying database SummaryAllProps with constraint filter in ("u", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 601006 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uz
# Querying database SummaryAllProps with constraint filter in ("u", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 551552 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db uy
# Querying database SummaryAllProps with constraint filter in ("u", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 565566 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gg
# Querying database SummaryAllProps with constraint filter in ("g", "g") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 201577 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gr
# Querying database SummaryAllProps with constraint filter in ("g", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 667438 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gi
# Querying database SummaryAllProps with constraint filter in ("g", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 671276 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gz
# Querying database SummaryAllProps with constraint filter in ("g", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 621822 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db gy
# Querying database SummaryAllProps with constraint filter in ("g", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 635836 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rr
# Querying database SummaryAllProps with constraint filter in ("r", "r") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 465861 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ri
# Querying database SummaryAllProps with constraint filter in ("r", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 935560 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db rz
# Querying database SummaryAllProps with constraint filter in ("r", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 886106 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ry
# Querying database SummaryAllProps with constraint filter in ("r", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 900120 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db ii
# Querying database SummaryAllProps with constraint filter in ("i", "i") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 469699 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iz
# Querying database SummaryAllProps with constraint filter in ("i", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 889944 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db iy
# Querying database SummaryAllProps with constraint filter in ("i", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 903958 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zz
# Querying database SummaryAllProps with constraint filter in ("z", "z") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 420245 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db zy
# Querying database SummaryAllProps with constraint filter in ("z", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 854504 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# >>>  wfd_depth_scale0.99_v1.5_10yrs.db yy
# Querying database SummaryAllProps with constraint filter in ("y", "y") and note not like '%DD%' for columns ['fieldRA', 'fieldDec', 'filter', 'fiveSigmaDepth', 'observationStartMJD']
# Found 434259 visits
# Running:  ['newMetricSky']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# CPU times: user 3h 53min 27s, sys: 1h 49min 52s, total: 5h 43min 20s
# Wall time: 6h 1min
