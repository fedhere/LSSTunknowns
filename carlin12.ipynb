# %%
import pandas as pd
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
carlin12f8 = pd.read_csv("data/carlin12f8.csv", header=None, names=["gr", "g"])

# %%
carlin12f8.plot.scatter(x='gr', y='g', figsize=(5,8))
pl.ylim(22,16)
# Out:
# (22, 16)

# %%
print("mean g")
carlin12f8.g.mean()
# Out:
# mean g
# 20.42517831669044

# %% [markdown]
# $d_{new}-d_{old} = 10^{(m_{new}-m_{old})/5}$

# %%
print(pow(10,(2)/5))
# Out:
# 2.51188643150958

# %%
7/5
# Out:
# 1.4

# %%
28*2.5
# Out:
# 70.0
